# %%
import pandas as pd

# %%
data = pd.read_csv('partial_data.csv')

# %%
data
# Out:
#                                       ICD Block Names  \
# 0   Abnormal findings on diagnostic imaging and in...
# 1   Abnormal findings on examination of blood, wit...
# 2   Abnormal findings on examination of blood, wit...
# 3   Abnormal findings on examination of blood, wit...
# 4   Abnormal findings on examination of blood, wit...
# 5   Abnormal findings on examination of blood, wit...
# 6   Abnormal findings on examination of blood, wit...
# 7   Abnormal findings on examination of blood, wit...
# 8   Accidental poisoning by and exposure to noxiou...
# 9                  Acute upper respiratory infections
# 10                 Acute upper respiratory infections
# 11                 Acute upper respiratory infections
# 12                 Acute upper respiratory infections
# 13                 Acute upper respiratory infections
# 14                 Acute upper respiratory infections
# 15                 Acute upper respiratory infections
# ...

# %%
results = pd.read_csv('results.csv')
results
# Out:
#                                        1st prediction  \
# 0   Malignant neoplasms of ill-defined, secondary ...
# 1                                   Diabetes mellitus
# 2                                   Diabetes mellitus
# 3                                   Diabetes mellitus
# 4                                   Diabetes mellitus
# 5   Complications of surgical and medical care, no...
# 6   Abnormal findings on examination of blood, wit...
# 7   Abnormal findings on examination of blood, wit...
# 8                          General symptoms and signs
# 9                  Acute upper respiratory infections
# 10          Bacterial agents resistant to antibiotics
# 11                 Acute upper respiratory infections
# 12                 Acute upper respiratory infections
# 13  Haemorrhagic and haematological disorders of f...
# 14                 Acute upper respiratory infections
# 15                 Acute upper respiratory infections
# ...
